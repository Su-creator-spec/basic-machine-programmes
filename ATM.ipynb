# %%
 def menu(self):
        user_input =input("""
               Hello,how would you like to proceed
              1. enter 1 to create pin
              2. enter 2 to deposit
              3. enter 3 to withdram
              4. enter 4 to check balance
              5. enter 5 to exit  """ )
        if user_input == "1":
            print("create pin")

        if user_input == "2":
            print("deposit")

        if user_input == "3":
            print("withdram")

        if user_input =="4":
            print("check the balnace")

        if user_input =="5":
            print("bye")





    def create_pin():
        self.pin =input("enter the pin")
        print("pin set sucessfully ")

    def deposit():
        temp=input("enter the pin:")
        if temp == self.pin:
            amount=int(input("enter the amount "))
            self.balance=self.balance+amount
        else:
            print("invaid pin")
    def withdraw():
        temp=input("enter the pin:")
        if temp == self.pin:
            amount=int(input("enter the amount:"))
            if amount<self.balance:
                self.balance=self.balance-amount
            else:
                print("insufficient balance")
        else:
            print("invalid pin")

    def check_balance():
        temp=input("enter the pin:")
        if temp == self.pin:
            print(self.balance)
        else:
            print("invalid pin ")
# Out:
#   File "<tokenize>", line 28
#     def create_pin():
#     ^
# IndentationError: unindent does not match any outer indentation level
